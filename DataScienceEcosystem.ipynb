# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ![2-title.png](attachment:c0ca3788-b564-4168-a414-3539074fbe32.png)

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# **Objectives:**
# - List most used languages
# - List most used libraries
# - List common used tools

# %% [markdown]
# ![3-intro.png](attachment:1fd3655a-430a-44c0-aa88-686ea9a5b524.png)

# %% [markdown]
# Some of the popular languages that Data Science use are:
# 1. Python
# 1. SQL
# 1. C++

# %% [markdown]
# ![4-dslanguages.png](attachment:6ce925c2-1c09-49bd-a579-64fc8d928a9c.png)

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# 1. Pandas
# 1. NumPy
# 1. Seaborn

# %% [markdown]
# ![5-dslibraries.png](attachment:5be61519-5d8b-4cf7-9e02-fb6afd669236.png)

# %% [markdown]
# |Data Science Tools|
# |------|
# |Jupyter notebook|
# |Spyder|
# |VS Code|

# %% [markdown]
# ![6-dstools.png](attachment:3900cbed-5c5b-49cd-ba00-047042826389.png)

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python.

# %% [markdown]
# ![introarithmetic.png](attachment:2ded9823-f321-4d4a-8017-c85fc4c80fbc.png)

# %%
## This is a simple arithmetic expression to multiply then add integers.
(3*4)+5
# Out:
# 17

# %% [markdown]
# ![8-multiplyandaddintegers.png](attachment:d1b58fae-6603-45fd-b959-8f8c526b4acc.png)

# %%
## This will convert 200 minutes to hours by dividing by 60.
200/60
# Out:
# 3.3333333333333335

# %% [markdown]
# ![9-minutestohours.png](attachment:ee8fdcf5-bb8c-481a-b09f-55080a08500f.png)

# %% [markdown]
# ![10-objectives.png](attachment:96b2bca0-4d1f-4e32-8a7e-7181e620422d.png)

# %% [markdown]
# ## Author
# Zuriñe Frías Cobián

# %% [markdown]
# ![11-authordetails.png](attachment:1ba1fd7d-8109-4daa-b4f2-e4ed770e08ee.png)
